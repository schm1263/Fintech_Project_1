# %%
import pandas as pd
import numpy as np
import panel as pn
import plotly.express as px

pn.extension("plotly")
# Out:
# C:\Users\prade\anaconda3\envs\pyvizenv\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\prade\anaconda3\envs\pyvizenv\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\prade\anaconda3\envs\pyvizenv\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)
# C:\Users\prade\anaconda3\envs\pyvizenv\lib\site-packages\xarray\core\merge.py:10: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
# Define function to create plot
housing_transactions = pd.DataFrame(
    {
        "years": np.random.randint(2010, 2019, 100),
        "sales": np.random.randint(53, 500, 100),
        "foreclosures": np.random.randint(10, 147, 100),
    }
).sort_values(["years", "sales"])

# Create plot
plot = px.scatter(
    housing_transactions,
    x="sales",
    y="foreclosures",
    color="years",
    title="Alleghany, PA Housing Transactions",
)

# %%
# Wrap Plotly object by explicitly declaring Panel pane
pane = pn.pane.Plotly(plot)
pane
# Out:
# Plotly(Figure)

# %%
# Wrap Plotly object by using panel.panel helper function
pn.panel(plot)
# Out:
# Plotly(Figure)

# %%
# Print the type of object
pane.pprint()
# Out:
# Plotly(Figure, relayout_data={'autosize': True}, viewport={'xaxis.range': [25.963082...})
